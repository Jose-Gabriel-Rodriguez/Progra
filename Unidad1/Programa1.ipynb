# %% [markdown]
# <a href="https://colab.research.google.com/github/Jose-Gabriel-Rodriguez/Progra/blob/main/Unidad1/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programacion Orientada a Objetos
#
# ## Unidad 1
#
# ### **Programa 1. Introduccion a Python**
#
# NOmbre del alumno: _________________
#
# Facilitador: José Gabriel Rodríguez Rivas

# %%
# Variables en Python
x = 20
print(x)
# Out:
# 20

# %%
print("La variable x es igual a", x)
# Out:
# La variable x es igual a Hola

# %%
x = "Hola"

# %%
print(x *5)
# Out:
# HolaHolaHolaHolaHola

# %%
a = 1000
b = 3000
if a > b:
  print("a es mayor que b")
  print(a, "es mayor que ", b)
else:
  print("b es mayor que a")
  print(b, " es mayor que ", a )
# Out:
# b es mayor que a
# 3000  es mayor que  1000

# %%
a = 1
while a < 10:
  print(a)
  print("Dentro del while")
  a = a + 1
print("Fuera del While")
# Out:
# 1
# Dentro del while
# 2
# Dentro del while
# 3
# Dentro del while
# 4
# Dentro del while
# 5
# Dentro del while
# 6
# Dentro del while
# 7
# Dentro del while
# 8
# Dentro del while
# 9
# Dentro del while
# Fuera del While

# %%
for i in range(5,11):
  print(i)
# Out:
# 5
# 6
# 7
# 8
# 9
# 10
